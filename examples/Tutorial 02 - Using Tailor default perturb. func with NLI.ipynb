# %%
# %load_ext autoreload
# %autoreload 2
is_cuda = True

# %% [markdown]
# # Overview
#
# This notebook is a more advanced demo on how to create perturbations for the Natural Language Inference task, using [SNLI dataset](https://www.google.com/search?hl=zh-CN&q=huggingface+snli). It describes in detail the running steps in Tailor (i.e., explains the implementation logic to some extent). If this does not look like the level of detail you are looking for, we recommend checking out the Basic Demo notebook.

# %% [markdown]
# ## Load the data

# %%
import datasets
import pandas as pd

# %%
def show_as_dataframe(list_of_namedtuples, keys=None):
    if isinstance(list_of_namedtuples[0], list):
        if not keys:
            keys = range(len(list_of_namedtuples))
        return pd.concat([pd.DataFrame(tup_list) for tup_list in list_of_namedtuples], keys=keys)
    return pd.DataFrame(list_of_namedtuples)

# %%
# load the data
snli = datasets.load_dataset("snli")
# since SNLI has sentence pairs of (premise, hypothesis), 
# here we denote the perturbation target as the hypothesis sentence.
key_to_perturb = "hypothesis"
# Out:
# Reusing dataset snli (/home/alexisr/.cache/huggingface/datasets/snli/plain_text/1.0.0/1f60b67533b65ae0275561ff7828aad5ee4282d0e6f844fd148d05d3c6ea251b)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# take a look as some randome sentences in the training dataset
data_dict = snli["train"][20:70]
sentences = data_dict[key_to_perturb]
sentences
# Out:
# ['A man in a restaurant is waiting for his meal to arrive.',
#  'A blond man getting a drink of water from a fountain in the park.',
#  'A blond man wearing a brown shirt is reading a book on a bench in the park',
#  'A blond man drinking water from a fountain.',
#  'The friends scowl at each other over a full dinner table.',
#  'There are two woman in this picture.',
#  'The friends have just met for the first time in 20 years, and have had a great time catching up.',
#  'The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.',
#  'Two groups of rival gang members flipped each other off.',
#  'Two women hug each other.',
#  'A team is trying to score the games winning out.',
#  'A team is trying to tag a runner out.',
#  'A team is playing baseball on Saturn.',
#  'A school hosts a basketball game.',
#  'A high school is hosting an event.',
#  'A school is hosting an event.',
#  'The women do not care what clothes they wear.',
#  'Women are waiting by a tram.',
#  'The women enjoy having a good fashion sense.',
#  'A child with mom and dad, on summer vacation at the beach.',
#  'A family of three is at the beach.',
#  'A family of three is at the mall shopping.',
#  'The people waiting on the train are sitting.',
#  'There are people just getting on a train',
#  'There are people waiting on a train.',
#  'A couple are playing with a young child outside.',
#  'A couple are playing frisbee with a young child at the beach.',
#  'A couple watch a little girl play by herself on the beach.',
#  'The family is sitting down for dinner.',
#  'The family is outside.',
#  'The family is on vacation.',
#  'The people are standing still on the curb.',
#  'Near a couple of restaurants, two people walk across the street.',
#  'The couple are walking across the street together.',
#  'The woman is nake.',
#  'The woman is cold.',
#  'The woman is wearing green.',
#  'The man with the sign is caucasian.',
#  'They are protesting outside the capital.',
#  'A woman in white.',
#  'A man is advertising for a restaurant.',
#  'The woman is wearing black.',
#  'A man and a woman walk down a crowded city street.',
#  'The woman is wearing white.',
#  "They are working for John's Pizza.",
#  'Olympic swimming.',
#  "A man and a soman are eating together at John's Pizza and Gyro.",
#  'They are walking with a sign.',
#  'The woman is waiting for a friend.',
#  "The man is sitting down while he has a sign for John's Pizza and Gyro in his arms."]

# %% [markdown]
# ## Preprocess the data
#
# Tailor handles semantic perturbation by taking advantage of sentences' semantic roles. Thus, we need to do some preprocessing to augment the texts with semantic features. We provide:
# - built-in SpaCy processor, and
# - SRL tagger ([default model from AllenNLP](https://demo.allennlp.org/semantic-role-labeling)).

# %%
from tailor.steps.process_with_spacy import GetSpacyModel, ProcessWithSpacy

# there are also two additional default parameters; Can change them if you need.
# spacy_model_name="en_core_web_sm"
# use_white_space_tokenizer=False
spacy_model = GetSpacyModel().run(parse=True)
spacy_outputs = ProcessWithSpacy().run(sentences=sentences, spacy_model=spacy_model)
spacy_outputs
# Out:
# [A man in a restaurant is waiting for his meal to arrive.,
#  A blond man getting a drink of water from a fountain in the park.,
#  A blond man wearing a brown shirt is reading a book on a bench in the park,
#  A blond man drinking water from a fountain.,
#  The friends scowl at each other over a full dinner table.,
#  There are two woman in this picture.,
#  The friends have just met for the first time in 20 years, and have had a great time catching up.,
#  The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.,
#  Two groups of rival gang members flipped each other off.,
#  Two women hug each other.,
#  A team is trying to score the games winning out.,
#  A team is trying to tag a runner out.,
#  A team is playing baseball on Saturn.,
#  A school hosts a basketball game.,
#  A high school is hosting an event.,
#  A school is hosting an event.,
#  The women do not care what clothes they wear.,
#  Women are waiting by a tram.,
#  The women enjoy having a good fashion sense.,
#  A child with mom and dad, on summer vacation at the beach.,
#  A family of three is at the beach.,
#  A family of three is at the mall shopping.,
#  The people waiting on the train are sitting.,
#  There are people just getting on a train,
#  There are people waiting on a train.,
#  A couple are playing with a young child outside.,
#  A couple are playing frisbee with a young child at the beach.,
#  A couple watch a little girl play by herself on the beach.,
#  The family is sitting down for dinner.,
#  The family is outside.,
#  The family is on vacation.,
#  The people are standing still on the curb.,
#  Near a couple of restaurants, two people walk across the street.,
#  The couple are walking across the street together.,
#  The woman is nake.,
#  The woman is cold.,
#  The woman is wearing green.,
#  The man with the sign is caucasian.,
#  They are protesting outside the capital.,
#  A woman in white.,
#  A man is advertising for a restaurant.,
#  The woman is wearing black.,
#  A man and a woman walk down a crowded city street.,
#  The woman is wearing white.,
#  They are working for John's Pizza.,
#  Olympic swimming.,
#  A man and a soman are eating together at John's Pizza and Gyro.,
#  They are walking with a sign.,
#  The woman is waiting for a friend.,
#  The man is sitting down while he has a sign for John's Pizza and Gyro in his arms.]

# %%
import logging
logging.getLogger("allennlp").setLevel("ERROR")

from tailor.steps.get_srl_tags import GetSRLTags
# the spacy-processed docs can be passed for getting the SRL labels
processed_sentences = GetSRLTags().run(spacy_outputs=spacy_outputs)

# %% [markdown]
# Take a look at one result. The result has the following structure:
#
# ```
# - sentence [str]: The original text.
# - spacy_doc [Spacy Doc]: The processed SpaCy doc.
# - verbs: A list of the predicates and their corresponding arguments
#     {
#         verb [str]: the verb
#             'training'
#         description: [str]: sentence with augmented semtnaic roles.
#             '[ARG0: A person] is [V: training] [ARG2: his horse] [ARG1: for a competition] .'
#         tags [List of str]:
#             Semantic roles in BIO format.
#     }[]
# ```

# %%
processed_sentences[0]
# Out:
# ProcessedSentence(sentence='A man in a restaurant is waiting for his meal to arrive .', spacy_doc=A man in a restaurant is waiting for his meal to arrive., verbs=[{'verb': 'is', 'description': 'A man in a restaurant [V: is] waiting for his meal to arrive .', 'tags': ['O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'waiting', 'description': '[ARG1: A man in a restaurant] is [V: waiting] [ARG2: for his meal to arrive] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'arrive', 'description': 'A man in a restaurant is waiting for [ARG1: his meal] to [V: arrive] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'O', 'B-V', 'O']}])

# %%
# See the result in a more structured formate
show_as_dataframe(processed_sentences)
# Out:
#                                              sentence  \
# 0   A man in a restaurant is waiting for his meal ...
# 1   A blond man getting a drink of water from a fo...
# 2   A blond man wearing a brown shirt is reading a...
# 3        A blond man drinking water from a fountain .
# 4   The friends scowl at each other over a full di...
# 5               There are two woman in this picture .
# 6   The friends have just met for the first time i...
# 7   The two sisters saw each other across the crow...
# 8   Two groups of rival gang members flipped each ...
# 9                          Two women hug each other .
# 10  A team is trying to score the games winning out .
# 11             A team is trying to tag a runner out .
# 12             A team is playing baseball on Saturn .
# 13                 A school hosts a basketball game .
# 14                A high school is hosting an event .
# 15                     A school is hosting an event .
# 16     The women do not care what clothes they wear .
# 17                      Women are waiting by a tram .
# 18      The women enjoy having a good fashion sense .
# 19  A child with mom and dad , on summer vacation ...
# 20                A family of three is at the beach .
# 21        A family of three is at the mall shopping .
# 22      The people waiting on the train are sitting .
# 23           There are people just getting on a train
# 24              There are people waiting on a train .
# 25  A couple are playing with a young child outside .
# 26  A couple are playing frisbee with a young chil...
# 27  A couple watch a little girl play by herself o...
# 28            The family is sitting down for dinner .
# 29                            The family is outside .
# 30                        The family is on vacation .
# 31        The people are standing still on the curb .
# 32  Near a couple of restaurants , two people walk...
# 33  The couple are walking across the street toget...
# 34                                The woman is nake .
# 35                                The woman is cold .
# 36                       The woman is wearing green .
# 37               The man with the sign is caucasian .
# 38          They are protesting outside the capital .
# 39                                 A woman in white .
# 40            A man is advertising for a restaurant .
# 41                       The woman is wearing black .
# 42  A man and a woman walk down a crowded city str...
# 43                       The woman is wearing white .
# 44               They are working for John 's Pizza .
# 45                                 Olympic swimming .
# 46  A man and a soman are eating together at John ...
# 47                     They are walking with a sign .
# 48                The woman is waiting for a friend .
# 49  The man is sitting down while he has a sign fo...
#
#                                             spacy_doc  \
# 0   (A, man, in, a, restaurant, is, waiting, for, ...
# 1   (A, blond, man, getting, a, drink, of, water, ...
# 2   (A, blond, man, wearing, a, brown, shirt, is, ...
# 3   (A, blond, man, drinking, water, from, a, foun...
# 4   (The, friends, scowl, at, each, other, over, a...
# 5      (There, are, two, woman, in, this, picture, .)
# 6   (The, friends, have, just, met, for, the, firs...
# 7   (The, two, sisters, saw, each, other, across, ...
# 8   (Two, groups, of, rival, gang, members, flippe...
# 9                   (Two, women, hug, each, other, .)
# 10  (A, team, is, trying, to, score, the, games, w...
# 11  (A, team, is, trying, to, tag, a, runner, out, .)
# 12    (A, team, is, playing, baseball, on, Saturn, .)
# 13         (A, school, hosts, a, basketball, game, .)
# 14       (A, high, school, is, hosting, an, event, .)
# 15             (A, school, is, hosting, an, event, .)
# 16  (The, women, do, not, care, what, clothes, the...
# 17              (Women, are, waiting, by, a, tram, .)
# 18  (The, women, enjoy, having, a, good, fashion, ...
# 19  (A, child, with, mom, and, dad, ,, on, summer,...
# 20      (A, family, of, three, is, at, the, beach, .)
# 21  (A, family, of, three, is, at, the, mall, shop...
# 22  (The, people, waiting, on, the, train, are, si...
# 23  (There, are, people, just, getting, on, a, train)
# 24     (There, are, people, waiting, on, a, train, .)
# 25  (A, couple, are, playing, with, a, young, chil...
# 26  (A, couple, are, playing, frisbee, with, a, yo...
# 27  (A, couple, watch, a, little, girl, play, by, ...
# 28   (The, family, is, sitting, down, for, dinner, .)
# 29                      (The, family, is, outside, .)
# 30                 (The, family, is, on, vacation, .)
# 31  (The, people, are, standing, still, on, the, c...
# 32  (Near, a, couple, of, restaurants, ,, two, peo...
# 33  (The, couple, are, walking, across, the, stree...
# 34                          (The, woman, is, nake, .)
# 35                          (The, woman, is, cold, .)
# 36                (The, woman, is, wearing, green, .)
# 37      (The, man, with, the, sign, is, caucasian, .)
# 38  (They, are, protesting, outside, the, capital, .)
# 39                           (A, woman, in, white, .)
# 40   (A, man, is, advertising, for, a, restaurant, .)
# 41                (The, woman, is, wearing, black, .)
# 42  (A, man, and, a, woman, walk, down, a, crowded...
# 43                (The, woman, is, wearing, white, .)
# 44      (They, are, working, for, John, 's, Pizza, .)
# 45                             (Olympic, swimming, .)
# 46  (A, man, and, a, soman, are, eating, together,...
# 47             (They, are, walking, with, a, sign, .)
# 48       (The, woman, is, waiting, for, a, friend, .)
# 49  (The, man, is, sitting, down, while, he, has, ...
#
#                                                 verbs
# 0   [{'verb': 'is', 'description': 'A man in a res...
# 1   [{'verb': 'getting', 'description': '[ARG0: A ...
# 2   [{'verb': 'wearing', 'description': '[ARG0: A ...
# 3   [{'verb': 'drinking', 'description': '[ARG0: A...
# 4   [{'verb': 'scowl', 'description': '[ARG0: The ...
# 5   [{'verb': 'are', 'description': 'There [V: are...
# 6   [{'verb': 'have', 'description': 'The friends ...
# 7   [{'verb': 'saw', 'description': '[ARG0: The tw...
# 8   [{'verb': 'flipped', 'description': '[ARG0: Tw...
# 9   [{'verb': 'hug', 'description': '[ARG0: Two wo...
# 10  [{'verb': 'is', 'description': 'A team [V: is]...
# 11  [{'verb': 'is', 'description': 'A team [V: is]...
# 12  [{'verb': 'is', 'description': 'A team [V: is]...
# 13  [{'verb': 'hosts', 'description': '[ARG0: A sc...
# 14  [{'verb': 'is', 'description': 'A high school ...
# 15  [{'verb': 'is', 'description': 'A school [V: i...
# 16  [{'verb': 'do', 'description': 'The women [V: ...
# 17  [{'verb': 'are', 'description': 'Women [V: are...
# 18  [{'verb': 'enjoy', 'description': '[ARG0: The ...
# 19                                                 []
# 20  [{'verb': 'is', 'description': '[ARG1: A famil...
# 21  [{'verb': 'is', 'description': '[ARG1: A famil...
# 22  [{'verb': 'waiting', 'description': '[ARG1: Th...
# 23  [{'verb': 'are', 'description': 'There [V: are...
# 24  [{'verb': 'are', 'description': 'There [V: are...
# 25  [{'verb': 'are', 'description': 'A couple [V: ...
# 26  [{'verb': 'are', 'description': 'A couple [V: ...
# 27  [{'verb': 'play', 'description': 'A couple wat...
# 28  [{'verb': 'is', 'description': 'The family [V:...
# 29  [{'verb': 'is', 'description': '[ARG1: The fam...
# 30  [{'verb': 'is', 'description': '[ARG1: The fam...
# 31  [{'verb': 'are', 'description': 'The people [V...
# 32  [{'verb': 'walk', 'description': '[ARGM-LOC: N...
# 33  [{'verb': 'are', 'description': 'The couple [V...
# 34  [{'verb': 'is', 'description': '[ARG1: The wom...
# 35  [{'verb': 'is', 'description': '[ARG1: The wom...
# 36  [{'verb': 'is', 'description': 'The woman [V: ...
# 37  [{'verb': 'is', 'description': '[ARG1: The man...
# 38  [{'verb': 'are', 'description': 'They [V: are]...
# 39                                                 []
# 40  [{'verb': 'is', 'description': 'A man [V: is] ...
# 41  [{'verb': 'is', 'description': 'The woman [V: ...
# 42  [{'verb': 'walk', 'description': '[ARG0: A man...
# 43  [{'verb': 'is', 'description': 'The woman [V: ...
# 44  [{'verb': 'are', 'description': 'They [V: are]...
# 45                                                 []
# 46  [{'verb': 'are', 'description': 'A man and a s...
# 47  [{'verb': 'are', 'description': 'They [V: are]...
# 48  [{'verb': 'is', 'description': 'The woman [V: ...
# 49  [{'verb': 'is', 'description': 'The man [V: is...

# %% [markdown]
# ## Tailor perturbations on sentences
#
# Now we start to do perturbations on the processed sentences.

# %%
from tailor.common.perturb_function import ChangeVoice, SwapCoreWithContext, SwapCoreWithoutContext, ShortenCoreArgument, ChangeTense
from tailor.steps.perturb_prompt import PerturbPromptWithString, PerturbPromptWithFunction
from tailor.steps.combine_all_prompts import CombineAllPrompts

# %%
sentence_prompts = []
perturbs = {
    ChangeVoice: "preserves_meaning",
    ShortenCoreArgument: "preserves_meaning",
    SwapCoreWithContext: "changes_meaning",
    SwapCoreWithoutContext: "changes_meaning",
}
for perturb_fn in [ChangeVoice, SwapCoreWithContext, SwapCoreWithoutContext, ShortenCoreArgument]:
    perturbations = PerturbPromptWithString().run(
        # the procssed sentence
        processed_sentences=processed_sentences, 
        # we have pre-implemented some functions you can call
        perturb_str_func=perturb_fn(), 
        # you can add arbitrary descriptions
        description=perturbs[perturb_fn])
    sentence_prompts.append(perturbations)
# Out:
#   0%|                                                                                 | 0/50 [00:00<?, ?it/s]No prompts created; unique_tlemmas: set()
# 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 102.00it/s]
#   0%|                                                                                 | 0/50 [00:00<?, ?it/s]Warning. Perturbed prompt is same as base prompt. This should not be happening.
# 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 122.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 112.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 50/50 [00:29<00:00,  1.70it/s]

# %%
# the available pre-defined functions: 
from tailor.common.perturb_function import PerturbStringFunction
PerturbStringFunction.list_available()
# Out:
# ['change_voice',
#  'change_tense',
#  'change_lemma',
#  'delete_text',
#  'delete_punctuation',
#  'swap_core_with_context',
#  'swap_core_without_context',
#  'shorten_core_argument']

# %%
# additionally, Tailor allows defining perturbation functions. 
# We will not go into details, but please feel free to check the implementaiton.

from tailor.tasks.nli.perturbations import ReplaceCoreWithSubsequence

# %%
replace_core_with_subs = PerturbPromptWithFunction().run(
    processed_sentences=processed_sentences, 
    perturb_fn=ReplaceCoreWithSubsequence(), 
    description="changes_meaning")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 50/50 [00:37<00:00,  1.34it/s]

# %%
sentence_prompts.append(replace_core_with_subs)

# %%
sentence_prompts = CombineAllPrompts().run(sentence_prompts)

# %%
# Here we generate the actual inputs to Tailor (the prompt column). 
# Note that the name and description are preserved for future reference.
show_as_dataframe(sentence_prompts)
# Out:
#                                                  prompt  \
# 0  0  [VERB+passive+present: be]  <extra_id_0> <extr...
#    1  [VERB+passive+present: wait | PATIENT+complete...
#    2  [VERB+passive+present: arrive | PATIENT+comple...
# 1  0  [VERB+passive+present: get | AGENT+complete: b...
#    1  [VERB+active+present: get | AGENT+complete: A ...
# ...                                                 ...
# 49 1  [VERB+passive+present: sit | PATIENT+complete:...
#    2  [VERB+passive+present: have | AGENT+complete: ...
#    3  [VERB+active+present: have | AGENT+partial: A ...
#    4  [VERB+active+present: have | AGENT+partial: A ...
#    5  [VERB+active+present: have | AGENT+complete: H...
#
#                                                  answer  \
# 0  0  A man in a restaurant [VERB: is] waiting for h...
#    1  [PATIENT: A man in a restaurant] is [VERB: wai...
#    2  A man in a restaurant is waiting for [PATIENT:...
# 1  0  [AGENT: A blond man] [VERB: getting] [PATIENT:...
#    1  [PATIENT: A blond man] [VERB: getting] [AGENT:...
# ...                                                 ...
# 49 1  [PATIENT: The man] is [VERB: sitting] down [TE...
#    2  The man is sitting down while [AGENT: he] [VER...
#    3  The man is sitting down while [PATIENT: he] [V...
#    4  The man is sitting down while [PATIENT: he] [V...
#    5  The man is sitting down while [AGENT: he] [VER...
#
#                                                    meta  \
# 0  0  {'noncore_args': [], 'core_args': [], 'blank_i...
#    1  {'noncore_args': [{'tlemma': 'for his meal to ...
#    2  {'noncore_args': [], 'core_args': [{'tlemma': ...
# 1  0  {'noncore_args': [{'tlemma': 'from a fountain ...
#    1  {'noncore_args': [{'tlemma': 'from a fountain ...
# ...                                                 ...
# 49 1  {'noncore_args': [{'tlemma': 'while he has a s...
#    2  {'noncore_args': [], 'core_args': [{'tlemma': ...
#    3  {'noncore_args': [], 'core_args': [{'tlemma': ...
#    4  {'noncore_args': [], 'core_args': [{'tlemma': ...
#    5  {'noncore_args': [], 'core_args': [{'tlemma': ...
#
#                            name        description
# 0  0               change_voice  preserves_meaning
#    1               change_voice  preserves_meaning
#    2               change_voice  preserves_meaning
# 1  0               change_voice  preserves_meaning
#    1     swap_core_with_context    changes_meaning
# ...                         ...                ...
# 49 1               change_voice  preserves_meaning
#    2               change_voice  preserves_meaning
#    3     swap_core_with_context    changes_meaning
#    4  swap_core_without_context    changes_meaning
#    5      shorten_core_argument  preserves_meaning
#
# [200 rows x 5 columns]

# %%
from tailor.common.utils.model_utils import load_generator

generator = load_generator()

# %%
# finally we can make the actual generation using the prompts.

from tailor.steps.generate_from_prompts import GenerateFromPrompts

generations = GenerateFromPrompts().run(
    processed_sentences=processed_sentences,
    prompts=sentence_prompts,
    spacy_model=spacy_model,
    compute_perplexity=True,
    generator=generator,
    max_length=75,
    num_perturbations=1,
)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 2/2 [00:09<00:00,  4.60s/it]
# 100%|████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 7740.92it/s]

# %%
show_as_dataframe(generations[1])
# Out:
#                                     prompt_no_header  \
# 0  I'm [VERB: getting] [PATIENT: a drink of water...
# 1  [AGENT: A drink of water] [VERB: gets] - [PATI...
# 2  [AGENT: A drink of water] [VERB: gets]'[PATIEN...
# 3  - [AGENT: a blond man] [VERB: gets]'[PATIENT- ...
# 4  [AGENT: A blond man] [VERB: gets] a drink of w...
# 5  Almost] a blond man] [VERB: gets] to [PATIENT:...
#
#                                             sentence  \
# 0  I 'm getting a drink of water - by blond man |...
# 1  A drink of water gets - a blond man -- from ''...
# 2  A drink of water gets ' a blond man -- from , ...
# 3                           - a blond man gets ' ee-
# 4     A blond man gets a drink of water ] " ooh . ''
# 5      Almost ] a blond man ] gets to spout of water
#
#                                       clean_sentence  \
# 0  I'm getting a drink of water-by blond man | fr...
# 1  A drink of water gets-a blond man--from'' spit...
# 2  A drink of water gets' a blond man--from, foun...
# 3                              a blond man gets' ee-
# 4        A blond man gets a drink of water ]" ooh.''
# 5      Almost ] a blond man ] gets to spout of water
#
#                                                 meta  \
# 0  {'match': '<re.Match object; span=(0, 27), mat...
# 1  {'match': '<re.Match object; span=(0, 26), mat...
# 2  {'match': '<re.Match object; span=(0, 26), mat...
# 3  {'match': '<re.Match object; span=(0, 26), mat...
# 4  {'match': '<re.Match object; span=(0, 26), mat...
# 5  {'match': '<re.Match object; span=(0, 26), mat...
#
#                                          annotations  \
# 0  [{'tag': 'VERB', 'start': 2, 'end': 3, 'pred':...
# 1  [{'tag': 'AGENT', 'start': 0, 'end': 4, 'pred'...
# 2  [{'tag': 'AGENT', 'start': 0, 'end': 4, 'pred'...
# 3  [{'tag': 'AGENT', 'start': 1, 'end': 4, 'pred'...
# 4  [{'tag': 'AGENT', 'start': 0, 'end': 3, 'pred'...
# 5  [{'tag': 'VERB', 'start': 6, 'end': 7, 'pred':...
#
#                                                words  vidx  \
# 0  [I, 'm, getting, a, drink, of, water, -, by, b...     3
# 1  [A, drink, of, water, gets, -, a, blond, man, ...     4
# 2  [A, drink, of, water, gets, ', a, blond, man, ...     4
# 3                   [-, a, blond, man, gets, ', ee-]     4
# 4  [A, blond, man, gets, a, drink, of, water, ], ...     3
# 5  [Almost, ], a, blond, man, ], gets, to, spout,...     6
#
#                             name        description is_valid  \
# 0                   change_voice  preserves_meaning     None
# 1         swap_core_with_context    changes_meaning     None
# 2      swap_core_without_context    changes_meaning     None
# 3          shorten_core_argument  preserves_meaning     None
# 4          shorten_core_argument  preserves_meaning     None
# 5  replace_core_with_subsequence    changes_meaning     None
#
#                                         perplexities
# 0  {'pr_sent': 56.27299499511719, 'pr_phrase': -3...
# 1   {'pr_sent': 83.90037155151367, 'pr_phrase': 0.0}
# 2   {'pr_sent': 58.69119644165039, 'pr_phrase': 0.0}
# 3  {'pr_sent': 7.019298553466797, 'pr_phrase': 7....
# 4   {'pr_sent': 33.38823318481445, 'pr_phrase': 0.0}
# 5  {'pr_sent': 37.33604049682617, 'pr_phrase': 24...

# %% [markdown]
# ## Data augmentation with Tailor
#
# Tailor also has additional steps that can support data augmentation.

# %%
from tailor.tasks.nli.augment import AugmentNLI

new_data = AugmentNLI().run(
    # these are perturbation settings we used at the beginning.
    dataset=data_dict, 
    perturbed_field=key_to_perturb, 
    # with the keywords of "changed_meaning" and "preserved_meaning", we can auto-label the new examples.
    generated_prompt_dicts=generations, 
    max_augment_per_instance=4)
# Out:
# 50it [00:00, 50051.36it/s]

# %%
# we can conver them into Huggingface dataset format.

from tailor.steps.convert_dataset_to_dict import ConvertDictToDataset
new_dataset = ConvertDictToDataset().run(new_data)

new_dataset
# Out:
# Dataset({
#     features: ['premise', 'hypothesis', 'label', 'perturbation_strategy'],
#     num_rows: 72
# })

# %%
new_dataset[:]
# Out:
# {'premise': ['A blond man getting a drink of water from a fountain in the park.',
#   'A blond man getting a drink of water from a fountain in the park.',
#   'A blond man getting a drink of water from a fountain in the park.',
#   'A blond man getting a drink of water from a fountain in the park.',
#   'A blond man wearing a brown shirt is reading a book on a bench in the park',
#   'A blond man wearing a brown shirt is reading a book on a bench in the park',
#   'A blond man wearing a brown shirt is reading a book on a bench in the park',
#   'A blond man wearing a brown shirt is reading a book on a bench in the park',
#   'A blond man drinking water from a fountain.',
#   'A blond man drinking water from a fountain.',
#   'A blond man drinking water from a fountain.',
#   'A blond man drinking water from a fountain.',
#   'The friends scowl at each other over a full dinner table.',
#   'The friends scowl at each other over a full dinner table.',
#   'The friends scowl at each other over a full dinner table.',
#   'The friends scowl at each other over a full dinner table.',
#   'The friends have just met for the first time in 20 years, and have had a great time catching up.',
#   'The friends have just met for the first time in 20 years, and have had a great time catching up.',
#   'The friends have just met for the first time in 20 years, and have had a great time catching up.',
#   'The friends have just met for the first time in 20 years, and have had a great time catching up.',
#   'The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.',
#   'The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.',
#   'The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.',
#   'The two sisters saw each other across the crowded diner and shared a hug, both clutching their doggie bags.',
#   'Two groups of rival gang members flipped each other off.',
#   'Two groups of rival gang members flipped each other off.',
#   'Two groups of rival gang members flipped each other off.',
#   'Two groups of rival gang members flipped each other off.',
#   'Two women hug each other.',
#   'Two women hug each other.',
#   'Two women hug each other.',
#   'Two women hug each other.',
#   'A team is trying to score the games winning out.',
#   'A team is trying to score the games winning out.',
#   'A team is trying to score the games winning out.',
#   'A team is trying to tag a runner out.',
#   'A team is trying to tag a runner out.',
#   'A team is trying to tag a runner out.',
#   'A team is trying to tag a runner out.',
#   'A team is playing baseball on Saturn.',
#   'A team is playing baseball on Saturn.',
#   'A team is playing baseball on Saturn.',
#   'A school hosts a basketball game.',
#   'A school hosts a basketball game.',
#   'A high school is hosting an event.',
#   'A school is hosting an event.',
#   'A school is hosting an event.',
#   'The women do not care what clothes they wear.',
#   'The women do not care what clothes they wear.',
#   'The women do not care what clothes they wear.',
#   'The women do not care what clothes they wear.',
#   'The women enjoy having a good fashion sense.',
#   'The women enjoy having a good fashion sense.',
#   'A couple are playing with a young child outside.',
#   'A couple are playing frisbee with a young child at the beach.',
#   'A couple watch a little girl play by herself on the beach.',
#   'The people are standing still on the curb.',
#   'Near a couple of restaurants, two people walk across the street.',
#   'The woman is wearing green.',
#   'They are protesting outside the capital.',
#   'A man is advertising for a restaurant.',
#   'The woman is wearing black.',
#   'The woman is wearing black.',
#   'A man and a woman walk down a crowded city street.',
#   'A man and a woman walk down a crowded city street.',
#   'The woman is wearing white.',
#   "They are working for John's Pizza.",
#   "They are working for John's Pizza.",
#   "A man and a soman are eating together at John's Pizza and Gyro.",
#   'They are walking with a sign.',
#   "The man is sitting down while he has a sign for John's Pizza and Gyro in his arms.",
#   "The man is sitting down while he has a sign for John's Pizza and Gyro in his arms."],
#  'hypothesis': ["A drink of water gets' a blond man--from, fountain in the park.",
#   "a blond man gets' ee-",
#   "I'm getting a drink of water-by blond man | from s fountain in the park",
#   'A blond man gets a drink of water ]" ooh.\'\'',
#   "A book on a bench in the park'' reading ta blond man wearing eel shirt",
#   "A book on a bench in the park'' reads s blond man wearing d. m",
#   'A blond man wearing a c-',
#   "''-a book on bbc in the park, read by blond man wearing cbs",
#   "' A blond man drinks hydr",
#   'a blond man drinking-water',
#   'a blond man drinking, water',
#   'water, drunk afs and steamed by a blond man from heartstastique.',
#   'the friends scowl-at each other',
#   'gotten GGGGRRg: by the friends ah in en-mishy in the mouth oaths of her ear jar]. Hs ianderata to the foodew',
#   "The friends' are scowling at each other--",
#   "' At each other, scowling the friends * over a full dinner table",
#   "The friends' had a great time catching up",
#   "A great time catching up have just met for the first time in 20 years, and've had a the friends",
#   'Having just gotten met by the friends in for the first time in 20 years',
#   'Having the friends, met',
#   'The two sisters saw each other across the crowded diner and shared a hug, Their doggie bags clutching-both',
#   'their doggie bags are clutched by both.',
#   'Having seen each other across the crowded diner',
#   'Having seen each other, the two sisters',
#   "Two groups of rival gang members' flipped each other off.",
#   "each other's flipped by two groups of rival gang members",
#   'Each other flipped-off members.',
#   "' Each other flipped-two groups of rival gang members",
#   "Each other's hugging two women.",
#   "Hugging each other'' by two women",
#   'Each other hugging, woman',
#   'Two women hug, each other',
#   'The is been ] won a>]',
#   'A team, trying to-do a job ; attempting sexist aims and practices based on race and ethnicity: vs. team size / style versus team ratio to score the games winning out',
#   'A team scores, the games winning out',
#   "' A team, trying to tag a runner out",
#   'A runner tags a team',
#   "Lonelier f a team by a teams ] s to tag next year,-LRB-n't enough... by an team",
#   "A team's tagging a runner out.",
#   '\'\' Baseball, playing a team--on saturn".',
#   'Baseball plays a d the m r]] at l.',
#   "A team's playing baseball",
#   "a basketball game'' is hosted by-school",
#   "A school's hosting game--",
#   "A high school's hosting event",
#   'an event is hosted by a school.',
#   "A school's hosting an event",
#   'What clothes they wear does not care-the women',
#   'They wear-what clothes',
#   'The women care, what clothes they wear',
#   "what clothes they wear's not cared for] at all.",
#   'The women have a s good fashion sense',
#   "The women's enjoy having a good fashion sense",
#   'Played-outside ; by a couple with a young child',
#   'Frisbee\'s VERB: playing--with, uh.-" at the beach"',
#   'a little girl ] playing.',
#   "These Those few have heard their ji are themselves ] they're still d y. on the curb standing is a y U, m n t fucked up in the concrete slab",
#   "two people're walking",
#   "The woman's wearing green",
#   "they're protesting.",
#   'A man advertises, for a restaurant.',
#   "The woman's wearing black",
#   "woman's black by her",
#   'Getting walked by a man and a woman ] the would [ver liqf[/ huhnds djesses',
#   'a man and / woman walk.',
#   'The woman wearing a white',
#   "they're working",
#   "They are working be by them.-LRW-] for john's pizza",
#   'a man and soman, eat [Cafes] and',
#   'they walk.',
#   "s wife and son are the man'd been sitting while he has a sign for john'' has pizza and gyro in his arms and hands",
#   "He has a sign for john's pizza and gyro in his arms ]--LRB-he'll be right back"],
#  'label': ['neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'neutral',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  'perturbation_strategy': ['swap_core_without_context',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'swap_core_without_context',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'replace_core_with_subsequence',
#   'change_voice',
#   'replace_core_with_subsequence',
#   'change_voice',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'change_voice',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'change_voice',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'swap_core_with_context',
#   'swap_core_without_context',
#   'swap_core_with_context',
#   'change_voice',
#   'swap_core_without_context',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'swap_core_without_context',
#   'change_voice',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'swap_core_without_context',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'swap_core_with_context',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'swap_core_without_context',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument',
#   'shorten_core_argument',
#   'change_voice',
#   'shorten_core_argument']}

# %%
for idx, row in enumerate(new_dataset):
    if row['label'] == 'neutral':
        print(idx)
# Out:
# 0
# 4
# 5
# 10
# 12
# 15
# 17
# 20
# 26
# 27
# 28
# 30
# 36
# 39
# 40
# 47
# 54

# %%
new_dataset[25]
# Out:
# {'premise': 'Two groups of rival gang members flipped each other off.',
#  'hypothesis': "each other's flipped by two groups of rival gang members",
#  'label': 'entailment',
#  'perturbation_strategy': 'change_voice'}

# %%
new_dataset[26]
# Out:
# {'premise': 'Two groups of rival gang members flipped each other off.',
#  'hypothesis': 'Each other flipped-off members.',
#  'label': 'neutral',
#  'perturbation_strategy': 'swap_core_with_context'}

# %%
new_dataset[45]
# Out:
# {'premise': 'A school is hosting an event.',
#  'hypothesis': 'an event is hosted by a school.',
#  'label': 'entailment',
#  'perturbation_strategy': 'change_voice'}
